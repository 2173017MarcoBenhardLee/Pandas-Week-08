# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.4
# 1.20.3

# %%
n_rows = 40
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns = cols)
df.head()
# Out:
#     A   B   C   D   E
# 0  19   5  17   4  14
# 1   7  19  10   8   7
# 2   7  14   3   9  15
# 3  16  16  13  19   8
# 4  17  11  19  10   3

# %% [markdown]
# Line plot

# %%
df.plot(kind ='line')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Bar plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   5  17   4  14
# 1   7  19  10   8   7
# 2   7  14   3   9  15
# 3  16  16  13  19   8
# 4  17  11  19  10   3

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].head().plot(kind='barh') # Tambah barh = horizontal bar plot
# Out:
# <AxesSubplot:>

# %% [markdown]
# Area Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   5  17   4  14
# 1   7  19  10   8   7
# 2   7  14   3   9  15
# 3  16  16  13  19   8
# 4  17  11  19  10   3

# %%
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].head().plot(kind='area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Box Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   5  17   4  14
# 1   7  19  10   8   7
# 2   7  14   3   9  15
# 3  16  16  13  19   8
# 4  17  11  19  10   3

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Histogram

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   5  17   4  14
# 1   7  19  10   8   7
# 2   7  14   3   9  15
# 3  16  16  13  19   8
# 4  17  11  19  10   3

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['A','B']].head().plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Kernel Density Estimation (KDE)

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   5  17   4  14
# 1   7  19  10   8   7
# 2   7  14   3   9  15
# 3  16  16  13  19   8
# 4  17  11  19  10   3

# %%
df.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Scatter Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   5  17   4  14
# 1   7  19  10   8   7
# 2   7  14   3   9  15
# 3  16  16  13  19   8
# 4  17  11  19  10   3

# %%
df.plot(x='A', y='B', kind='scatter')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>
